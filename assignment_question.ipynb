# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
x=input("enter a number")
print(x)
# Out:
# enter a number12
# 12

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
x = int(input("enter a number"))
if x>0:
  print("positive")
elif x<0:
    print("negative")
else:
    print("zero")
# Out:
# enter a number12
# positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
from ast import And
# Your code here
x=int(input("enter a 1st number"))
y=int(input("enter a 2nd number"))
z=int(input("enter a 3rd number"))
if x>y and x>z:
  print("1st number is greater number")
elif y>x and y>z:
  print("2nd number is greate number")
else:
  print("number 3rd is greater number")
# Out:
# enter a 1st number12
# enter a 2nd number22
# enter a 3rd number32
# number 3rd is greater number

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
x=int(input("enter a number to ifnd its factorial"))
if x<0:
  result = "factorial doesnt exist"
elif x==0:
  result= 1
else:
  result=1
  for i in range(1, x+1):
    result=result*i

print(result)
# Out:
# enter a number to ifnd its factorial12
# 479001600

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
var= 5
print(var,type(var))
var="hello"
print(var,type(var))
var=5.1
print(var,type(var))
var=True
print(var,type(var))
# Out:
# 5 <class 'int'>
# hello <class 'str'>
# 5.1 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
x=int(input("enter x value="))
y=int(input("enter y value="))
print("value of x before swap",x)
print("value of y before swap",y)
x,y = y,x
print("value of x after swap",x)
print("value of y after swap",y)
# Out:
# enter x value=12
# enter y value=23
# value of x before swap 12
# value of y before swap 23
# value of x after swap 23
# value of y after swap 12

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
temp= float(input("enter the temp in c to covert to f= "))
result = (temp*9/5)+32
print(result)
# Out:
# enter the temp in c to covert to f= 12
# 53.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
x="hello"
y="world"
z= x+y
print(z)
# Out:
# helloworld

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var=int(input("enter a var to check if it int"))
if type(var)==int:
  print("var is int")
else:
  print("var if not int")
# Out:
# enter a var to check if it int12
# var is int

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a=int(input("enter number a"))
b=int(input("enter number b"))
add=a+b
subs=a-b
multi=a*b
div=a/b
print("addition",add)
print("substraction",subs)
print("multiplication",multi)
print("division",div)
# Out:
# enter number a12
# enter number b24
# addition 36
# substraction -12
# multiplication 288
# division 0.5

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a=2
b=5
a<b
# Out:
# True

# %%
# Your code here
a>b
a==b
a!=b
# Out:
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
a=4
sq=a**2
print(sq)
# Out:
# 16

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
a=2
if a%2 == 0:
  print("even")
else:
  print("odd")
# Out:
# even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n=int(input("enter n value"))
if n<1:
  print("0")

total_sum=(n*(n+1))//2
print(total_sum)
# Out:
# enter n value12
# 78

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
''' leap yr once in 4yrs but yrs divisible by 100 is not leap unless divisible by 400 tooo '''
n=int(input("enter the yr to cheap leap or no "))
if n%100 and n%400 == 0:
  print("leap year", n)
else:
  print("not a leap yr")
# Out:
# enter the yr to cheap leap or no 1900
# not a leap yr

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str=input("enter string to reverse")
revStr=""
for char in str:
  revStr=char+revStr
print(revStr)
# Out:
# enter string to reverseaba
# aba

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
if revStr == str:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
number = [20,90,40,70,80]
number.sort()
print(number)
# Out:
# [20, 40, 70, 80, 90]
